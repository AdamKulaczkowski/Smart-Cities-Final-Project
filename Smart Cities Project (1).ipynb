# %%
# load necessary packages
import Pkg; Pkg.add("PrettyTables"); Pkg.add("VegaLite")
using JuMP, GLPK
using Plots; plotly();
using VegaLite  # to make some nice plots
using DataFrames, CSV, PrettyTables
ENV["COLUMNS"]=120;
# Out:
#    Updating registry at `~/.julia/registries/General`
# ┌ Warning: could not download https://pkg.julialang.org/registries
# └ @ Pkg.Types /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.5/Pkg/src/Types.jl:951
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`
# ┌ Info: For saving to png with the Plotly backend PlotlyBase has to be installed.
# └ @ Plots /Users/adamkulaczkowski/.julia/packages/Plots/oZheM/src/backends.jl:372

# %%
gen_info = CSV.read("GeneratorsWithRamp.csv", DataFrame);
fuels = CSV.read("Fuels_dataSmartCities.csv", DataFrame);
loads = CSV.read("Demandfinal.csv", DataFrame);
gen_variable = CSV.read("Generator_variability.csv", DataFrame);

# Rename all columns to lowercase (by convention)
for f in [gen_info, fuels, loads, gen_variable]
    rename!(f,lowercase.(names(f)))
end

# %%
gen_info
# Out:
# 25×12 DataFrame
#  Row │ r_id   resource  name                               existing_cap_mw  num_units  cap_size  var_om_cost_per_mwh   ⋯
#      │ Int64  String    String                             Float64          Int64      Float64   Int64                 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    1 │     1  WT        Steel Winds Wind Farm                        20.0           1    20.0                      0   ⋯
#    2 │     2  WT        Steel Winds II                               15.0           1    15.0                      0
#    3 │     3  PV        Steel Sun 2 2303-III-2 Hamburg T…             2.0           1     2.0                      0
#    4 │     4  PV        Steel Sun 2 2303-III-4 Hamburg T…             2.0           1     2.0                      0
#    5 │     5  PV        Steel Sun 2 2303-III-9 Hamburg T…             2.0           1     2.0                      0   ⋯
# ...

# %%
# Keep only the columns relevant to our ED model 
# (We'll come back to other columns in our unit commitment notebooks)
select!(gen_info, 1:12) # columns 1:10 and cluster IDs
gen_df = outerjoin(gen_info,  fuels, on = :fuel) # load in fuel costs and add to data frame
rename!(gen_df, :cost_per_mmbtu => :fuel_cost)   # rename column for fuel cost
gen_df.fuel_cost[ismissing.(gen_df[:,:fuel_cost])] .= 0

# create "is_variable" column to indicate if this is a variable generation source (e.g. wind, solar):
gen_df[!, :is_variable] .= false
gen_df = gen_df[1:25,:]
gen_df[in(["WT","PV","HY"]).(gen_df.resource),:is_variable] .= true;

# create full name of generator (including geographic location and cluster number)
#  for use with variable generation dataframe
gen_df.gen_full = lowercase.(gen_df.resource);

# %%
gen_df
# Out:
# 25×16 DataFrame
#  Row │ r_id    resource  name                               existing_cap_mw  num_units  cap_size  var_om_cost_per_mwh  ⋯
#      │ Int64?  String?   String?                            Float64?         Int64?     Float64?  Int64?               ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    1 │      1  WT        Steel Winds Wind Farm                        20.0           1    20.0                      0  ⋯
#    2 │      2  WT        Steel Winds II                               15.0           1    15.0                      0
#    3 │      3  PV        Steel Sun 2 2303-III-2 Hamburg T…             2.0           1     2.0                      0
#    4 │      4  PV        Steel Sun 2 2303-III-4 Hamburg T…             2.0           1     2.0                      0
#    5 │      5  PV        Steel Sun 2 2303-III-9 Hamburg T…             2.0           1     2.0                      0  ⋯
# ...

# %%
CSV.write("gen_df.csv",gen_df)
# Out:
# "gen_df.csv"

# %%
gen_variable_long = stack(gen_variable, 
                        Not(:hour), 
                        variable_name=:gen_full,
                        value_name=:cf);

# %%
#=
Function to solve economic dispatch problem (multi-time period, single-zone)
Inputs:
    gen_df -- dataframe with generator info
    loads  -- load by time
    gen_variable -- capacity factors of variable generators (in "long" format)
=#
function economic_dispatch_multi(gen_df, loads, gen_variable)
    ED = Model(GLPK.Optimizer)

    # Define sets based on data
    G_var = gen_df[gen_df[!,:is_variable] .== 1,:r_id] 
    G_nonvar = gen_df[gen_df[!,:is_variable] .== 0,:r_id]
    G = gen_df.r_id
    T = loads.hour
    T_red = loads.hour[1:end-1]  # time periods used for ramp constraints
    
    # Generator capacity factor time series for variable generators
    gen_var_cf = innerjoin(gen_variable, 
                    gen_df[gen_df.is_variable .== 1 , 
                        [:r_id, :gen_full, :existing_cap_mw]], 
                    on = :gen_full)
        
    # Decision variables   
    @variables(ED, begin
        GEN[G, T]  >= 0     # generation
        # Note: we assume Pmin = 0 for all resources for simplicty here
    end)
                
    # Objective function
    @objective(ED, Min, 
        sum( (gen_df[gen_df.r_id .== i,:heat_rate_mmbtu_per_mwh][1] * gen_df[gen_df.r_id .== i,:fuel_cost][1] +
            gen_df[gen_df.r_id .== i,:var_om_cost_per_mwh][1]) * GEN[i,t] 
                        for i in G_nonvar for t in T) + 
        sum(gen_df[gen_df.r_id .== i,:var_om_cost_per_mwh][1] * GEN[i,t] 
                        for i in G_var for t in T)
    )
    
    # Demand constraint
    @constraint(ED, cDemand[t in T], 
        sum(GEN[i,t] for i in G) == loads[loads.hour .== t,:demand][1])

    # Capacity constraints (non-variable generation)
    @constraint(ED, Cap_nonvar[i in G_nonvar, t in T], 
        GEN[i,t] <= gen_df[gen_df.r_id .== i,:existing_cap_mw][1])

    # Variable generation capacity constraints
    @constraint(ED, Cap_var[i in 1:nrow(gen_var_cf)], 
            GEN[gen_var_cf[i,:r_id], gen_var_cf[i,:hour] ] <= 
                        gen_var_cf[i,:cf] *
                        gen_var_cf[i,:existing_cap_mw])
    
    # Ramp up constraints
    @constraint(ED, RampUp[i in G, t in T_red], 
        GEN[i,t+1] - GEN[i,t] <= gen_df[gen_df.r_id .== i,:existing_cap_mw][1] * 
                                 gen_df[gen_df.r_id .== i,:ramp_up_percentage][1] )

    # Ramp down constraints
    @constraint(ED, RampDn[i in G, t in T_red], 
        GEN[i,t] - GEN[i,t+1] <= gen_df[gen_df.r_id .== i,:existing_cap_mw][1] * 
                                 gen_df[gen_df.r_id .== i,:ramp_dn_percentage][1] )
    
    # Solve statement (! indicates runs in place)
    optimize!(ED)

    # Dataframe of optimal decision variables
    # This requires a few extra steps because we are indexing decision variables over two sets: generator and time
    solution = DataFrame(value.(GEN).data)
    ax1 = value.(GEN).axes[1]
    ax2 = value.(GEN).axes[2]
    cols = names(solution)
    insertcols!(solution, 1, :r_id => ax1)
    solution = stack(solution, Not(:r_id), variable_name=:hour)
    solution.hour = foldl(replace, [cols[i] => ax2[i] for i in 1:length(ax2)], init=solution.hour)
    rename!(solution, :value => :gen)
    solution.hour = convert.(Int64,solution.hour)
    
    # Return the solution and objective as named tuple
    return (
        solution = solution, 
        cost = objective_value(ED),
        status = termination_status(ED)
    )

end
# Out:
# economic_dispatch_multi (generic function with 1 method)

# %%
#solve a week's economic dispatch

T_period = (1):(168)

loads = loads[in.(loads.hour,Ref(T_period)),:]
gen_variable = gen_variable_long[in.(gen_variable_long.hour,Ref(T_period)),:]
# Out:
# 504×3 DataFrame
#  Row │ hour   gen_full  cf
#      │ Int64  String    Float64
# ─────┼──────────────────────────
#    1 │     1  pv          0.0
#    2 │     2  pv          0.0
#    3 │     3  pv          0.0
#    4 │     4  pv          0.0
#    5 │     5  pv          0.0
#    6 │     6  pv          0.0
#    7 │     7  pv          0.035
#    8 │     8  pv          0.123
#    9 │     9  pv          0.301
#   10 │    10  pv          0.472
#   11 │    11  pv          0.609
#   ⋮  │   ⋮       ⋮         ⋮
#  495 │   159  hy          1.0
#  496 │   160  hy          1.0
#  497 │   161  hy          1.0
#  498 │   162  hy          1.0
#  499 │   163  hy          1.0
#  500 │   164  hy          1.0
#  501 │   165  hy          1.0
#  502 │   166  hy          0.66
#  503 │   167  hy          0.66
#  504 │   168  hy          0.66
#                 483 rows omitted

# %%
solution = economic_dispatch_multi(gen_df, loads, gen_variable);

# %%
function emissions(solution)
    sol_gen = innerjoin(solution.solution, 
                    gen_df[!, [:r_id, :resource]], 
                    on = :r_id)
    sol_gen = combine(groupby(sol_gen, [:resource, :hour]), 
            :gen => sum)

    # Reorder resources
    sort!(sol_gen, [:hour, :resource])
    
    sol_gen_sum = combine(groupby(sol_gen, [:resource]), :gen_sum => sum)
    emissions = (sol_gen_sum[2,:gen_sum_sum])*3.412*117
end
# Out:
# emissions (generic function with 1 method)

# %%
trial1 = emissions(solution)
# Out:
# 6.0116194312480785e7

# %%
sol_gen = innerjoin(solution.solution, 
                    gen_df[!, [:r_id, :resource]], 
                    on = :r_id)
sol_gen = combine(groupby(sol_gen, [:resource, :hour]), 
            :gen => sum)

# Reorder resources
sort!(sol_gen, [:hour, :resource])
# Out:
# 1008×3 DataFrame
#   Row │ resource  hour   gen_sum
#       │ String?   Int64  Float64
# ──────┼───────────────────────────
#     1 │ BM            1    0.0
#     2 │ CC            1  819.676
#     3 │ HY            1  281.794
#     4 │ PS            1  240.0
#     5 │ PV            1    0.0
#     6 │ WT            1   27.63
#     7 │ BM            2    0.0
#     8 │ CC            2  775.586
#     9 │ HY            2  281.794
#    10 │ PS            2  240.0
#    11 │ PV            2    0.0
#   ⋮   │    ⋮        ⋮       ⋮
#   999 │ HY          167  281.794
#  1000 │ PS          167  240.0
#  1001 │ PV          167    0.0
#  1002 │ WT          167  103.152
#  1003 │ BM          168    0.0
#  1004 │ CC          168  906.714
#  1005 │ HY          168  281.794
#  1006 │ PS          168  240.0
#  1007 │ PV          168    0.0
#  1008 │ WT          168   85.1925
#                   987 rows omitted

# %%
sol_gen_sum = combine(groupby(sol_gen, [:resource]), :gen_sum => sum)
# Out:
# 6×2 DataFrame
#  Row │ resource  gen_sum_sum
#      │ String?   Float64
# ─────┼────────────────────────
#    1 │ BM            0.0
#    2 │ CC            1.5059e5
#    3 │ HY        62583.8
#    4 │ PS        40320.0
#    5 │ PV          766.751
#    6 │ WT         8797.39

# %%
tot_demand = sum(sol_gen_sum[!,:gen_sum_sum])
# Out:
# 263058.0999999998

# %%
sol_gen |>
@vlplot(:area, 
    x=:hour, y={:gen_sum, stack=:zero}, 
    color={"resource:n", scale={scheme="category20"}})
# Out:
# @vlplot(
#     mark="area",
#     encoding={
#         x={
#             field="hour"
#         },
#         y={
#             stack="zero",
#             field="gen_sum"
#         },
#         color={
#             scale={
#                 scheme="category20"
#             },
#             field="resource",
#             type="nominal"
#         }
#     },
#     data={
#         values=...
#     }
# )

# %%
sol_gen |>
@vlplot(:line, 
    x=:hour, y=:gen_sum, 
    color={"resource:n", scale={scheme="category20"}})
# Out:
# @vlplot(
#     mark="line",
#     encoding={
#         x={
#             field="hour"
#         },
#         y={
#             field="gen_sum"
#         },
#         color={
#             scale={
#                 scheme="category20"
#             },
#             field="resource",
#             type="nominal"
#         }
#     },
#     data={
#         values=...
#     }
# )

# %%
tot_demand = sum(sol_gen_sum[!,:gen_sum_sum]) 
percentage_ren = (sol_gen_sum[3,:gen_sum_sum]+sol_gen_sum[4,:gen_sum_sum]+sol_gen_sum[5,:gen_sum_sum]+
    sol_gen_sum[6,:gen_sum_sum])/tot_demand*100 
print("The percentage of total demand that is renewable is ", percentage_ren, "%")
# Out:
# The percentage of total demand that is renewable is 42.75403030737315%

# %%
#Increase wind and solar power until target emissions are reached
trial1 = emissions(solution)
target_emissions = 14023028;
gen_df_wind = copy(gen_df)
while trial1 > target_emissions
    gen_df_wind[gen_df_wind.name .== "Noble Bliss Windpark LLC",:existing_cap_mw] .= 
         gen_df_wind[gen_df_wind.name .== "Noble Bliss Windpark LLC",:existing_cap_mw] .+ 50
    gen_df_wind[gen_df_wind.name .== "AES Tonawanda Solar LLC",:existing_cap_mw] .= 
         gen_df_wind[gen_df_wind.name .== "AES Tonawanda Solar LLC",:existing_cap_mw] .+ 50
    global meeting_emissions = economic_dispatch_multi(gen_df_wind, loads, gen_variable)
    trial1 = emissions(meeting_emissions)
end

# %%
sol_gen_wind = innerjoin(meeting_emissions.solution, 
                    gen_df[!, [:r_id, :resource]], 
                    on = :r_id)
sol_gen_wind = combine(groupby(sol_gen_wind, [:resource, :hour]), 
            :gen => sum)

# Reorder resources
sort!(sol_gen_wind, [:hour, :resource])
sol_gen_sum_wind = combine(groupby(sol_gen_wind, [:resource]), :gen_sum => sum)
sol_gen_wind |>
@vlplot(:area, 
    x=:hour, y={:gen_sum, stack=:zero}, 
    color={"resource:n", scale={scheme="category20"}})
# Out:
# @vlplot(
#     mark="area",
#     encoding={
#         x={
#             field="hour"
#         },
#         y={
#             stack="zero",
#             field="gen_sum"
#         },
#         color={
#             scale={
#                 scheme="category20"
#             },
#             field="resource",
#             type="nominal"
#         }
#     },
#     data={
#         values=...
#     }
# )

# %%
gen_df_wind[gen_df_wind.name .== "Noble Bliss Windpark LLC",:existing_cap_mw]
# Out:
# 1-element Array{Union{Missing, Float64},1}:
#  3900.5

# %%
gen_df_wind[gen_df_wind.name .== "AES Tonawanda Solar LLC",:existing_cap_mw]
# Out:
# 1-element Array{Union{Missing, Float64},1}:
#  3802.0

# %%
tot_demand_wind = sum(sol_gen_sum_wind[!,:gen_sum_sum]) 
percentage_ren_wind = (sol_gen_sum_wind[3,:gen_sum_sum]+sol_gen_sum_wind[4,:gen_sum_sum]+sol_gen_sum_wind[5,:gen_sum_sum]+
    sol_gen_sum_wind[6,:gen_sum_sum])/tot_demand_wind*100 
print("The percentage of total demand that is renewable is ", percentage_ren_wind, "%")
# Out:
# The percentage of total demand that is renewable is 86.68397057532157%

# %%
#Create more strict ramping constraints
gen_df_strict = copy(gen_df)
gen_df_strict[:,:ramp_up_percentage] .= gen_df_strict[:,:ramp_up_percentage].*0.01
solution_strict = economic_dispatch_multi(gen_df_strict, loads, gen_variable);

# %%
gen_df_strict[:,:ramp_up_percentage]
# Out:
# 25-element Array{Union{Missing, Float64},1}:
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.0378
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01
#  0.01

# %%
sol_gen_strict = innerjoin(solution_strict.solution, 
                    gen_df[!, [:r_id, :resource]], 
                    on = :r_id)
sol_gen_strict = combine(groupby(sol_gen_strict, [:resource, :hour]), 
            :gen => sum)

# Reorder resources
sort!(sol_gen_strict, [:hour, :resource])
sol_gen_sum_strict = combine(groupby(sol_gen_strict, [:resource]), :gen_sum => sum)
sol_gen_strict |>
@vlplot(:area, 
    x=:hour, y={:gen_sum, stack=:zero}, 
    color={"resource:n", scale={scheme="category20"}})
# Out:
# @vlplot(
#     mark="area",
#     encoding={
#         x={
#             field="hour"
#         },
#         y={
#             stack="zero",
#             field="gen_sum"
#         },
#         color={
#             scale={
#                 scheme="category20"
#             },
#             field="resource",
#             type="nominal"
#         }
#     },
#     data={
#         values=...
#     }
# )

# %%
trial2 = emissions(solution_strict)
target_emissions = 14023028;
gen_ren = copy(gen_df_strict)
while trial2 > target_emissions
    gen_ren[gen_ren.name .== "Noble Bliss Windpark LLC",:existing_cap_mw] .= 
         gen_ren[gen_ren.name .== "Noble Bliss Windpark LLC",:existing_cap_mw] .+ 50
    gen_ren[gen_ren.name .== "AES Tonawanda Solar LLC",:existing_cap_mw] .= 
         gen_ren[gen_ren.name .== "AES Tonawanda Solar LLC",:existing_cap_mw] .+ 50
    global strict_emissions = economic_dispatch_multi(gen_ren, loads, gen_variable)
    trial2 = emissions(strict_emissions)
end

# %%
sol_ren = innerjoin(strict_emissions.solution, 
                    gen_ren[!, [:r_id, :resource]], 
                    on = :r_id)
sol_ren = combine(groupby(sol_ren, [:resource, :hour]), 
            :gen => sum)

# Reorder resources
sort!(sol_ren, [:hour, :resource])
sol_ren_sum = combine(groupby(sol_ren, [:resource]), :gen_sum => sum)
sol_ren |>
@vlplot(:area, 
    x=:hour, y={:gen_sum, stack=:zero}, 
    color={"resource:n", scale={scheme="category20"}})
# Out:
# @vlplot(
#     mark="area",
#     encoding={
#         x={
#             field="hour"
#         },
#         y={
#             stack="zero",
#             field="gen_sum"
#         },
#         color={
#             scale={
#                 scheme="category20"
#             },
#             field="resource",
#             type="nominal"
#         }
#     },
#     data={
#         values=...
#     }
# )

# %%
gen_ren[gen_ren.name .== "AES Tonawanda Solar LLC",:existing_cap_mw]
# Out:
# 1-element Array{Union{Missing, Float64},1}:
#  17852.0

# %%
gen_ren[gen_ren.name .== "Noble Bliss Windpark LLC",:existing_cap_mw]
# Out:
# 1-element Array{Union{Missing, Float64},1}:
#  17950.5
